# %%
# %%HTML
# <style>
#
# td {
#     font-size: 100px
# }
#
#
# h1 {
#     font-size: 100px
# }
#
# </style>
# Out:
# <style>
#
# td {
#     font-size: 100px
# }
#
#
# h1 {
#     font-size: 100px
# }
#
# </style>

# %% [markdown]
# <td>Testing</td>

# %% [markdown]
# _this is italics_ <br>
# *this is italics* <br>
# __this is bold__ <br>
# **this is bold** <br>
# **_This is bold & italics_** <br>
# ~~strike_through this~~
# <h2 align=left>left-aligned text</h1>
# <h1 align=center>Centered text</h1>
# <h3 align=right>right-aligned text</h1>
#
# <br>
#
# >"This is a block quote" <br>
#
# #this is a code block <br>
#
# \\\so is this
#
# # H1<br>
# ## H2 <br>
# ### H3 <br>
# #### Header four <br>
# ##### Header five <br>
# ###### Header six <br>
# Headerless <br>
#
#
# **inline link**<br>
# [Visit GitHub!](www.github.com)
#
#
# **reference link**<br>
#
# [Link][beedotorg] <br>
# ⋮
# [beedotorg]: http://b.org
#
#
# **link to image** <br>
# ![A representation of Octdrey Catburn](http://octodex.github.com/images/octdrey-catburn.jpg)
#
# ---
# horzintal lines above & below
# ***
# <br>
# how to make `code` inline <br>
#
# **unordered list (bullets= *, -) <br>
# * item 1
# * item 2
#  * item 2a
# * item etc
# <br><br>
#
# **ordered list (number= 1) or 1.)**<br>
# 1. item 1
# 2. item 2
#        Own Box Here;
# 3. item etc
#
#
#
# **Poem w/ Soft Break**;<br>_2 blank space characters ('··') to soft break_ <br><br>
# We pictured the meek mild creatures where,··
# They dwelt in their strawy pen,··
# Nor did it occur to one of us there··
# To doubt they were kneeling then.

# %% [markdown]
# _this is italics_ <br>
# *this is italics* <br>
# __this is bold__ <br>
# **this is bold** <br>
# **_This is bold & italics_** <br>
# ~~strike_through this~~
# <center>Centered text</center>
# <br>
#
# >"This is a block quote" <br>
#
#     # this is a code block
#     \\\ so is this
#
# # H1<br>
# ## H2 <br>
# ### H3 <br>
# #### Header four <br>
# ##### Header five <br>
# ###### Header six <br>
# Headerless <br>
#
#
# **inline link**<br>
# [Visit GitHub!](www.github.com)
#
#
# **reference link**<br>
#
# [Link][beedotorg] <br>
# ⋮
# [beedotorg]: http://b.org
#
#
# **link to image** <br>
# ![A representation of Octdrey Catburn](http://octodex.github.com/images/octdrey-catburn.jpg)
#
# ---
# horzintal lines above & below
# ***
# <br>
# how to make `code` inline <br>
#
# **unordered list (bullets= *, -) <br>
# * item 1
# * item 2
#  * item 2a
# * item etc
# <br><br>
#
# **ordered list (number= 1) or 1.)**<br>
# 1. item 1
# 2. item 2
#        Own Box Here;
# 3. item etc
#
#
#
# **Poem w/ Soft Break**;<br>_2 blank space characters ('··') to soft break_ <br><br>
# We pictured the meek mild creatures where,··
# They dwelt in their strawy pen,··
# Nor did it occur to one of us there··
# To doubt they were kneeling then.

# %% [markdown]
# # MATH MARKDOWN
#
# [Adopted from Here](http://csrgxtu.github.io/2015/03/20/Writing-Mathematic-Fomulars-in-Markdown/)

# %% [markdown]
# $\alpha $ Alpha<br>
# $A $      A<br>
# $\beta$ Beta<br>
# $B $ B<br>
# $\gamma$ gamma<br>
# $\Gamma$ Gamma<br>
# $\pi$ pi<br>
# $\Pi$ Pi<br>
# $\phi$ Phi<br>
# $\Phi$ phi<br>
# $\varphi$ variable phi<br>
# $\theta$ theta<br>

# %% [markdown]
# $k_{n+1}$ <br>
# $n^2$<br>
# $k_n^2$<br>
#
# $\frac{n!}{k!(n-k)!}$<br>
# $\binom{n}{k}$<br>
# $\frac{\frac{x}{1}}{x - y}$<br>
# $^3/_7$<br>
#
# $\sqrt{k}$<br>
# $\sqrt[n]{k}$<br>
#
# $\sum$ <br>
#
#
#
# $\sum_{i=1}^{10} t_i$ <br>
# $\sum_{\substack{0<i<m\0<j<n}} P(i, j)$<br>
# $\int\limits_a^b$<br>
# $\int_0^\infty \mathrm{e}^{-x}\,\mathrm{d}x$<br>
